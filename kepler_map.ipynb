# %%
from keplergl import KeplerGl
import shapely
import geopandas as gpd
import pandas as pd

# %%
schools = pd.read_csv('/Users/oguz/Documents/Giga/Country Analysis/Brazil/Brazil-map/br_school_v4_lite.csv')
subdivision_stats = pd.read_csv('/Users/oguz/Documents/Giga/Country Analysis/Brazil/Brazil-map/br_avg_subdivision_stats_v4.csv')
# %run map_configuration.py

# %%
bra_map = KeplerGl(height=800, width=600, config=config ,show_docs=False, read_only=True,
                     data={'schools': schools.loc[:,['Source School ID','School Name','Latitude','Longitude','Internet Availability','Fiber Node Distance, km','Cell Tower Distance, km','4G Coverage','Max Mobile Generation','Population Within The 1 km Radius Zone']],
                           'subdivision_stats': subdivision_stats.loc[:,['WKT','Subdivision Name','Number Of Schools','% Of Unconnected Schools In The Subdivision','Avg. Fiber Node Distance, km','Avg. Cell Tower Distance, km','% Of 4G Covered Schools','Avg. Population Around Schools within 1km']],
                           }
                    )
bra_map
# Out:
# /Users/oguz/opt/anaconda3/envs/pyenv/lib/python3.8/site-packages/jupyter_client/session.py:718: UserWarning: Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#   content = self.pack(content)
# KeplerGl(data={'schools':         Source School ID                                        School Name  \
# 0    …

# %%
#This cell is to save configuration file of the map
config = bra_map.config
with open('map_configuration.py', 'w') as f:
    f.write('config = {}'.format(bra_map.config))

# %%
config
# Out:
# {'version': 'v1',
#  'config': {'visState': {'filters': [],
#    'layers': [{'id': 'hylbwoe',
#      'type': 'point',
#      'config': {'dataId': 'schools',
#       'label': 'Schools - Fiber Dist.',
#       'color': [30, 150, 190],
#       'highlightColor': [252, 242, 26, 255],
#       'columns': {'lat': 'Latitude', 'lng': 'Longitude', 'altitude': None},
#       'isVisible': True,
#       'visConfig': {'radius': 6,
#        'fixedRadius': False,
#        'opacity': 0.8,
#        'outline': False,
#        'thickness': 2,
#        'strokeColor': None,
#        'colorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#FFC300',
#          '#F1920E',
#          '#E3611C',
#          '#C70039',
#          '#900C3F',
#          '#5A1846'],
#         'reversed': True},
#        'strokeColorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
# ...

# %%
bra_map.save_to_html(config=config, file_name='Brazil_map_rw.html', read_only=False)
bra_map.save_to_html(config=config, file_name='Brazil_map_r.html', read_only=True)
# Out:
# Map saved to Brazil_map_rw.html!
# Map saved to Brazil_map_r.html!
